# %%
#IPython notebook plot formatting
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 10)

import matplotlib.pyplot as plt

#Load the modules
import Extractors as e
import Classifiers as c
import DoyleMLToolkit as dmlt

#Make sure they get reloaded after changes
e = reload(e)
c = reload(c)
dmlt = reload(dmlt)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Define high order models to generate accurate variances

CancerModels = [
    dmlt.Model(e.ComplexFourier,c.NaiveBayesReal,80,0),
    dmlt.Model(e.Chebyshev,c.NaiveBayesReal,80,0)
]


#Load relevant data

KidneySectionB = [model.load("kidney/BB1Class.csv","kidney/KidneyBB1.csv") for model in CancerModels]
KidneySectionC = [model.load("kidney/CC1Class.csv","kidney/KidneyCC1.csv") for model in CancerModels]

KidneyData = [KidneySectionB[i]+KidneySectionC[i] for i in range(len(KidneySectionB))]


#Generate variances
varReal = []
varImag = []
zeroth = 0
for model in KidneyData:
    varReal.append(model.getVariances(0,0,zeroth)[:3])
    varImag.append(model.getVariances(1,0,zeroth)[:3])
print varReal[0]
print varImag[0]
print ''
print varReal[1]
print varImag[1]
# Out:
# [0.62912137803246748, 0.1400353518589556, 0.062401559217721406]
# [0.95927404813067829, 0.014635593875304557, 0.003864774995619906]
#
# [0.00047978788157003872, 0.068674537626027168, 0.0031295795815113746]
# [0.85605898002430514, 0.1151981256751646, 0.011568901448556391]

# %%
#Plot Fourier variances
pylab.rcParams['figure.figsize'] = (16, 4)

#Real
objects = ('1','2','3')
y_pos = np.arange(len(objects))
performance = [100*i for i in varReal[0]]

plt.subplot(121)
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Percentage of Total Variation')
plt.xlabel('Principal Component')
plt.title('Fourier capacitance')

#Imaginary
objects = ('1','2','3')
y_pos = np.arange(len(objects))
performance = [100*i for i in varImag[0]]

plt.subplot(122)
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Percentage of Total Variation')
plt.xlabel('Principal Component')
plt.title('Fourier conductance')

plt.show()

# %%
#Plot Chebyshev variances

#Real
objects = ('1','2','3')
y_pos = np.arange(len(objects))
performance = [100*i for i in varReal[1]]

plt.subplot(121)
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Percentage of Total Variation')
plt.xlabel('Principal Component')
plt.title('Chebyshev capacitance')

#Imaginary
objects = ('1','2','3')
y_pos = np.arange(len(objects))
performance = [100*i for i in varImag[1]]

plt.subplot(122)
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Percentage of Total Variation')
plt.xlabel('Principal Component')
plt.title('Chebyshev conductance')

plt.show()

# %%
#Fourier component plots
pylab.rcParams['figure.figsize'] = (16, 5)

#Real
model = 0
imaginary = 0
classes = sorted(list(set(KidneyData[model].getAllY())))
colors = ['red','orange','yellow','green','blue']

x = 0
y = 0
plt.subplot(121)
for row in range(len(KidneyData[model].getAllFeatures()[0])):
    x = KidneyData[model].getFeaturesBySweep(row,0,imaginary)[0]
    y = KidneyData[model].getFeaturesBySweep(row,0,imaginary)[1]
    if KidneyData[model].getAllY()[row] == "Cancer":
        plt.plot([x],[y],color='#ff0000',marker='D',linewidth=0)
    else:
        plt.plot([x],[y],color='#000000',marker='o',linewidth=0)
    plt.annotate(str(row),(x+(1e-12),y+(3e-6)))

plt.title("Fourier capacitance")
plt.xlabel("1st Principal Component")
plt.ylabel("1st Principal Component")

#Imaginary
model = 0
imaginary = 1
classes = sorted(list(set(KidneyData[model].getAllY())))
colors = ['red','orange','yellow','green','blue']

x = 0
y = 0
plt.subplot(122)
for row in range(len(KidneyData[model].getAllFeatures()[0])):
    x = KidneyData[model].getFeaturesBySweep(row,0,imaginary)[0]
    y = KidneyData[model].getFeaturesBySweep(row,0,imaginary)[1]
    if KidneyData[model].getAllY()[row] == "Cancer":
        plt.plot([x],[y],color='#ff0000',marker='D',linewidth=0)
    else:
        plt.plot([x],[y],color='#000000',marker='o',linewidth=0)
    plt.annotate(str(row),(x-(1e-5),y+(0.9e-6)))

plt.title("Fourier conductance")
plt.xlabel("1st Principal Component")
plt.ylabel("1st Principal Component")
plt.show()

# %%
#Chebyshev component plots

#Real
model = 1
imaginary = 0
classes = sorted(list(set(KidneyData[model].getAllY())))
colors = ['red','orange','yellow','green','blue']

x = 0
y = 0
plt.subplot(121)
for row in range(len(KidneyData[model].getAllFeatures()[0])):
    x = KidneyData[model].getFeaturesBySweep(row,0,imaginary)[0]
    y = KidneyData[model].getFeaturesBySweep(row,0,imaginary)[1]
    if KidneyData[model].getAllY()[row] == "Cancer":
        plt.plot([x],[y],color='#ff0000',marker='D',linewidth=0)
    else:
        plt.plot([x],[y],color='#000000',marker='o',linewidth=0)
    plt.annotate(str(row),(x-(12e-15),y+(1e-15)))

plt.title("Chebyshev capacitance")
plt.xlabel("1st Principal Component")
plt.ylabel("1st Principal Component")

#Imaginary
model = 1
imaginary = 1
classes = sorted(list(set(KidneyData[model].getAllY())))
colors = ['red','orange','yellow','green','blue']

x = 0
y = 0
plt.subplot(122)
for row in range(len(KidneyData[model].getAllFeatures()[0])):
    x = KidneyData[model].getFeaturesBySweep(row,0,imaginary)[0]
    y = KidneyData[model].getFeaturesBySweep(row,0,imaginary)[1]
    if KidneyData[model].getAllY()[row] == "Cancer":
        plt.plot([x],[y],color='#ff0000',marker='D',linewidth=0)
    else:
        plt.plot([x],[y],color='#000000',marker='o',linewidth=0)
    plt.annotate(str(row),(x-(3e-8),y+(3e-8)))

plt.title("Chebyshev conductance")
plt.xlabel("1st Principal Component")
plt.ylabel("1st Principal Component")
plt.show()

# %%
#Redefine models at low orders to make actual classifications

CancerModels = [
     dmlt.Model(e.ComplexFourier,c.NaiveBayesReal,3,1),
     dmlt.Model(e.Chebyshev,c.NaiveBayesReal,3,1)
]


#Load relevant data

KidneySectionB = [model.load("kidney/BB1Class.csv","kidney/KidneyBB1.csv") for model in CancerModels]
KidneySectionC = [model.load("kidney/CC1Class.csv","kidney/KidneyCC1.csv") for model in CancerModels]

KidneyData = [KidneySectionB[i]+KidneySectionC[i] for i in range(len(KidneySectionB))]

# %%
#Fourier reconstructed plots

#Real
imaginary = 0
model = 0
plt.subplot(121)
CancerModels[model].plotSample(KidneyData[model],0,'orange',imaginary)
CancerModels[model].plotApproximation(KidneyData[model],0,'b--',imaginary)

#Imaginary
imaginary = 1
model = 0
plt.subplot(122)
CancerModels[model].plotSample(KidneyData[model],0,'orange',imaginary)
CancerModels[model].plotApproximation(KidneyData[model],0,'b--',imaginary)
plt.show()

# %%
#Chebyshev reconstructed plots

#Real
imaginary = 0
model = 1
plt.subplot(121)
CancerModels[model].plotSample(KidneyData[model],0,'orange',imaginary)
CancerModels[model].plotApproximation(KidneyData[model],0,'b--',imaginary)

#Imaginary
imaginary = 1
model = 1
plt.subplot(122)
CancerModels[model].plotSample(KidneyData[model],0,'orange',imaginary)
CancerModels[model].plotApproximation(KidneyData[model],0,'b--',imaginary)
plt.show()

# %%
#Redefine models at without zeroth to make actual classifications

order = 2
CancerModels = [
    dmlt.Model(e.ComplexFourier,c.NaiveBayesReal,order,zeroth),
    dmlt.Model(e.Chebyshev,c.NaiveBayesReal,order,zeroth),
    
    dmlt.Model(e.ComplexFourier,c.NaiveBayesImag,order,zeroth),
    dmlt.Model(e.Chebyshev,c.NaiveBayesImag,order,zeroth),


    dmlt.Model(e.ComplexFourier,c.NBKernelReal,order,zeroth),
    dmlt.Model(e.Chebyshev,c.NBKernelReal,order,zeroth),

    dmlt.Model(e.ComplexFourier,c.NBKernelImag,order,zeroth),
    dmlt.Model(e.Chebyshev,c.NBKernelImag,order,zeroth)
]


#Load relevant data

KidneySectionB = [model.load("kidney/BB1Class.csv","kidney/KidneyBB1.csv") for model in CancerModels]
KidneySectionC = [model.load("kidney/CC1Class.csv","kidney/KidneyCC1.csv") for model in CancerModels]

KidneyData = [KidneySectionB[i]+KidneySectionC[i] for i in range(len(KidneySectionB))]

# %%
#Test model

for model in range(len(CancerModels)):
    CancerModels[model].train(KidneyData[model],[],0)
    print CancerModels[model].C.name
    print CancerModels[model].L.name
    CancerModels[model].train(KidneyData[model],[],1)
    #CancerModels[model].predict(KidneyData[model],KidneyData[model].getAllY())
    print CancerModels[model].test(KidneyData[model],'Cancer')
    print ''
# Out:
# ComplexFourier
# Naive Bayes Real
# 0.357142857143 0.107142857143
# 0.0714285714286 0.464285714286
# [0.8214285714285714, 0.8125, 0.8666666666666667, 0.8387096774193549]
#
# Chebyshev
# Naive Bayes Real
# 0.214285714286 0.25
# 0.0714285714286 0.464285714286
# [0.6785714285714286, 0.65, 0.8666666666666667, 0.7428571428571429]
#
# ComplexFourier
# Naive Bayes Imaginary
# 0.178571428571 0.285714285714
# 0.107142857143 0.428571428571
# [0.6071428571428571, 0.6, 0.8, 0.6857142857142856]
#
# Chebyshev
# Naive Bayes Imaginary
# 0.214285714286 0.25
# 0.0357142857143 0.5
# [0.7142857142857143, 0.6666666666666666, 0.9333333333333333, 0.7777777777777779]
#
# ComplexFourier
# Kernel Density Estimation Real
# 0.321428571429 0.142857142857
# 0.0357142857143 0.5
# [0.8214285714285714, 0.7777777777777778, 0.9333333333333333, 0.8484848484848486]
#
# Chebyshev
# Kernel Density Estimation Real
# 0.178571428571 0.285714285714
# 0.0357142857143 0.5
# [0.6785714285714286, 0.6363636363636364, 0.9333333333333333, 0.7567567567567568]
#
# ComplexFourier
# Kernel Density Estimation Imaginary
# 0.178571428571 0.285714285714
# 0.107142857143 0.428571428571
# [0.6071428571428571, 0.6, 0.8, 0.6857142857142856]
#
# Chebyshev
# Kernel Density Estimation Imaginary
# 0.321428571429 0.142857142857
# 0.0357142857143 0.5
# [0.8214285714285714, 0.7777777777777778, 0.9333333333333333, 0.8484848484848486]
